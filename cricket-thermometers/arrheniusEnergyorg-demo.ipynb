# %% [markdown]
# # How much energy does a biological process need?

# %% [markdown]
# <a href="https://en.wikipedia.org/wiki/Oecanthus_fultoni" alt="Snowy Cricket" width="300px" style="float:right;margin:0px 0px 0px 10px;"><img src="./cricket-data/Snowytreecricket.JPG" alt="Snowy Cricket" width="300px" style="float:right;margin:0px 0px 0px 10px;" /></a>
# Biological processes typically involve complex sequences of chemical
# reactions. Rarely is it possible to model these processes precisely
# because the mechanisms are unknown. In many cases, however, it is
# reasonable to model the system as a single step reaction with a
# rate-determining step. Rate measurements can tell us if the process
# follows the
# <a href="https://en.wikipedia.org/wiki/Arrhenius_equation">Arrhenius law</a>.
# (Historical note: Arrhenius, through
# <a href="https://en.wikipedia.org/wiki/Svante_Arrhenius#Greenhouse_effect">radiative
# forcing calculations</a> in the late 1800's, predicted fossil fuel
# combustion would influence global climate.)
#
# In this exercise, the
# <a href="https://en.wikipedia.org/wiki/Stridulation">stridulation</a> (chirp)
# rate of the snowy tree cricket *Oecanthus* at different temperatures is
# modeled to see whether this process follows Arrhenius behavior.
#
# <a href="http://entnemdept.ufl.edu/walker/buzz/585a.htm">Singing Crickets of
# North America</a> has sound recordings for crickets, katydids, and
# cicadas. Cricket songs recorded at different temperatures give a sense
# of what the researchers from the 1800s were hearing and measuring
# (something many of us are familiar with).
#
# For example, the chirp rate at
# a relatively cool 13°C:

# %%
import IPython
IPython.display.Audio("cricket-data/585ssj.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Compare this with the chirp rate at a warm 25°C

# %%
IPython.display.Audio("cricket-data/585ssh.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Learning outcomes and prerequisites

# %% [markdown]
# ## Content learning outcomes

# %% [markdown]
# After completing this activity, you should be able to
#
# -   use provided rate data and the Arrhenius law to calculate the activation
#     energy of a process
# -   create and use a model that will predict the rate of a reaction

# %% [markdown]
# ## Process learning outcomes

# %% [markdown]
# After completing this activity, you should be able to
#
# -   import CSV data into numpy arrays
# -   plot numpy arrays
# -   perform linear and non-linear fitting to model functions
# -   use WebMO to calculate bond energies
# -   communicate the analysis process and results

# %% [markdown]
# ## Prerequisites

# %% [markdown]
# This activity assumes an understanding of
#
# -   rate laws and rate constants
# -   basic python syntax
# -   plotting with matplotlib
# -   assigning numpy arrays
#
# WU = Warm up, CTQ = Critical Thinking Question

# %% [markdown]
#  # Python environment
#  If using a cloud environment, plan to upload data files.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from scipy.stats import linregress

# %% [markdown]
# # Warm Up Questions

# %% [markdown]
# #### WU 1. Sketch a qualitative plot showing the energy profile of a one-step endothermic reaction $A \rightarrow B$. Identify key features of the plot.

# %% [markdown]
# <img src="./cricket-data/rxn-profile-axes.png" alt="rxn-profile-axes.png" />

# %% [markdown]
# #### WU 2. Compute (using python) the energy available to molecules at room temperature. Give your answer in J/molecule and kJ/mol.

# %% [markdown]
# #### WU 3.  Compared to the energy available at room temperature, how much energy is required for a typical biological process? Explain your thinking (even if it's just "wild guess").

# %% [markdown]
# #### WU 4. Which of the following graphs best describes how the rate constant for a typical chemical reaction depends on temperature?

# %% [markdown]
# <center><img src="./kvsT.png" width="60%"></center>
# Compare your answer with your group.

# %% [markdown]
# # Model 1: Reaction rates at two temperatures

# %% [markdown]
# The relationship between a reaction's rate at two temperatures depends on $E_a$ the activation energy:
#
# $$ \ln \dfrac{r_2}{r_1}=\dfrac{E_{\textrm a}}{R}\left(\dfrac{1}{T_1}-\dfrac{1}{T_2}\right) \nonumber $$
#
# $r_1$ and $r_2$ correspond to the rate at temperatures $T_1$ and $T_2$, respectively.
#
# The thermal energy available at room temperature is given by $kT$ (per molecule) or $RT$ (per mole): 4.1e-21 J/molec = 2.5 kJ/mol.
#
# **CTQ 1.** Assuming the rates have the same units, does it matter what those units are? Explain your reasoning.

# %% [markdown]
# **CTQ 2**. Assuming the temperatures have the same units, does it matter what those units are? Explain your reasoning.

# %% [markdown]
# ### Exercise 1

# %% [markdown]
# Use python to show that the energy available at room temperature agrees with the values given in the model. Remember to include units as a comment.

# %% [markdown]
# ### Exercise 2

# %% [markdown]
# As a group, use the audio files from the introduction to estimate the frequency of chirps of the snowy tree crickets at the two temperatures given. With these values, use Model 1 to calculate the activation energy of stridulation. In a text cell, describe your method and print the result with correct units and to a sensible number of significant figures.

# %% [markdown]
# ### Think about it

# %% [markdown]
# Compare the thermal energy available at room temperature to the activation energy of the chirping process. Using this comparison, and the information and sketch from the WU questions, summarize why cricket chirp rates might change with temperature.

# %% [markdown]
# # Model 2: Temperature dependence of a reaction rate

# %% [markdown]
# Eusuf and Laidler studied the <a href="https://cdnsciencepub.com/doi/pdf/10.1139/v64-276">thermal decomposition of acetaldehyde</a> and found the reaction is second order over the temperature range 600 - 1000 K. Table 1 provides temperature and rate constants using data from this study.
#
# **Table 1:** Rate constants for the decomposition of acetaldehyde at several temperatures <center><img src="./table1-moog.png" width="40%"></center>

# %% [markdown]
# ### CTQ 3.

# %% [markdown]
# Based on the data in Table 1, and without using a calculator, determine which (if any) of the following functional forms is likely to be a good description of the dependence of $k$ on $T$, where $A$ and $B$ are positive-valued constants:
#
# a) $k=A×T$
#
# b) $k = A /T$
#
# c) $k = A e^{BT}$
#
# d) $k = A e^{B/T}$
#
# e) $k = A e^{-B/T}$

# %% [markdown]
# ### CTQ 4.

# %% [markdown]
# For each of the two likely functional forms identified in the previous CTQ, linearize the function by hand. Next, describe the forms of $k$ and $T$ that, when plotted, will give straight line.

# %% [markdown]
# ## Exercise 3

# %% [markdown]
# Enter the data from Table 1 into numpy arrays, plot both of the functional forms from the previous CTQ, and identify the one that gives the straightest line.

# %% [markdown]
# Compare results with group.

# %% [markdown]
# # Model 3: The Arrhenius equation

# %% [markdown]
# The temperature dependence of rates can be modeled with the
# <a href="https://en.wikipedia.org/wiki/Arrhenius_equation">Arrhenius
# Equation</a>:
#
# $$ k = Ae^{-E_{a}/RT} \qquad\qquad\quad (1) $$
#
# or, in linear form:
#
# $$ \ln k = \frac{-E_a}{R} \frac{1}{T} + \ln(A)\qquad\qquad (2) $$
#
# where $A$=pre-exponential factor, $E_a$=activation energy, and $R$=gas
# constant.

# %% [markdown]
# ### CTQ 5.

# %% [markdown]
# According to equation (<a href="#org660def7">1</a>)  what are the units of $k$, $A$, and $T$ if the reaction is a) a first-order reaction b) a second-order reaction?

# %% [markdown]
# ### CTQ 6.

# %% [markdown]
# Identify the independent variable, dependent variable, and slope in a plot of equation (2).

# %% [markdown]
# # Importing CSV data

# %% [markdown]
# <a href="http://www.jstor.org/stable/2452666">Carl and Eduard Bessey</a> measured the chirp rate  of snowy tree crickets at different temperatures in Nebraska:
#
# <center><img src="cricket-data/chirp-temp.jpg" width="60%"></center>
#
# To extract the chirp/temp data pairs from
# the figure in <a href="http://www.jstor.org/stable/2452666">Bessey & Bessey,
# Am. Natur., 376, 1898, 263</a> , an image of the plot was cropped,
# exported as a jpeg file, and the points were digitzed using the web
# service <a href="https://automeris.io/WebPlotDigitizer/">WebPlotDigitizer</a>.
# The data points were saved as a comma separated values (CSV) file. Note
# that the "digitized" data points have MANY more significant digits than
# the original data; keep this in mind when assessing results.

# %% [markdown]
# ## Worked Example: Recreate the plot from Bessy & Bessy

# %% [markdown]
# First, examine the structure of `cricket-data/cricket.csv`. It may have
# header information that should be excluded.

# %%
# 'head' prints the first five lines of a file. "!" tells us it is a shell command
# !head -n 5 cricket-data/cricket.csv
# Out:
# Temp/F,Chirps/min
# 54.2672,76.65
# 54.5218,80.1263
# 56.3994,81.9654
# 57.3368,86.0579

# %% [markdown]
# The file provides a header line describing measured variables with
# units followed by comma-separated data values. Knowing this, we can skip
# the first line and read the data into numpy arrays.

# %%
# fn is the filename; colnames is a list of column names for the dataframe
tempF, rate = np.genfromtxt('cricket-data/cricket.csv', delimiter=',', skip_header=1, unpack=True)
tempF, rate
# Out:
# (array([54.2672, 54.5218, 56.3994, 57.3368, 58.476 , 59.3508, 59.4106,
#         59.4379, 59.9794, 60.2342, 60.9712, 61.3147, 62.4484, 63.477 ,
#         64.7528, 65.4655, 65.4955, 66.5137, 66.6266, 66.7108, 67.962 ,
#         68.9848, 69.2678, 69.4361, 69.4372, 70.9988, 71.37  , 71.9935,
#         73.4188, 74.726 , 74.9215, 74.9476, 75.0571, 75.3438, 75.3695,
#         76.1948, 76.4252, 77.0229, 77.4468, 78.164 , 78.411 , 78.9506,
#         80.656 , 80.7119, 80.903 , 82.0473, 82.5022, 82.873 ]),
#  array([ 76.65  ,  80.1263,  81.9654,  86.0579,  84.6813, 100.597 ,
#          94.5429,  96.8522,  95.4411,  98.3404, 104.729 , 100.71  ,
#         110.872 , 102.566 , 113.024 , 110.758 , 107.586 , 121.203 ,
#         123.228 , 125.541 , 128.209 , 132.018 , 135.496 , 140.698 ,
#         138.391 , 146.558 , 143.983 , 149.788 , 145.255 , 149.657 ,
#         157.457 , 162.362 , 171.599 , 167.289 , 173.06  , 173.396 ,
#         167.64  , 167.674 , 174.045 , 162.259 , 181.601 , 184.228 ,
# ...

# %% [markdown]
# ### CTQ 7

# %% [markdown]
# Four arguments were passed to `np.genfromtxt()`. Describe the python data type and purpose of each argument.
#
# (Here's an example: "*The names= argument takes a list of strings which are the dataframe column names*")

# %% [markdown]
# ### Exercise 4

# %% [markdown]
# Plot the imported data and compare to the original figure.

# %% [markdown]
# ### Exercise 5

# %% [markdown]
# Add axis labels and change axis limits, and use a point marker to mimic the original plot.

# %% [markdown]
# # Fitting data with curve\_fit

# %% [markdown]
# ## Worked Example: Fitting data with scipy.stats.linregress

# %% [markdown]
# Signature for `linregress()`

# %% [markdown]
# Use `linregress()` to perform a regression on the data.

# %%
x = np. array([ 0.,  1.4,  2.8,  4.3,  5.77, 7.2,  8.6, 10.1, 11.5, 13.])
y = np. array([ 0.29, 3.2, 2.6, 4.3, 5.5, 7.3, 8.7, 11.2, 14.4, 15.1])
reg = linregress(x, y)
print(reg)
# Out:
# LinregressResult(slope=np.float64(1.1306298424429686), intercept=np.float64(-0.052783191078678016), rvalue=np.float64(0.9817469940863349), pvalue=np.float64(4.750847183970626e-07), stderr=np.float64(0.07744032587905281), intercept_stderr=np.float64(0.5951544233682424))

# %% [markdown]
# Check the fit by generating y values based on the regression and plotting both the fit and the original data.

# %%
y_fit = x * reg.slope + reg.intercept 
plt.plot(x, y_fit, label='best fit')
plt.plot(x, y, 'o', label='data')
plt.legend()

# %% [markdown]
# # References

# %% [markdown]
# -   Laidler, *J. Chem. Educ*., 49, **1972**, 343 <a href="http://pubs.acs.org/doi/abs/10.1021/ed049p343">DOI:10.1021/ed049p343</a>.
# -   Myers, *J. Chem. Educ.*, 67, 9, **1990**, 761.
# -   Schapley, *Proc. Natl. Acad. Sci.*, 6, **1920**, 205.
# -   Spencer, Moog, Farrell, *Physical Chemistry, A Guided Inquiry: Thermodynamics*, Houghton Mifflin, 2004, 281.
# -   Engel and Reid, *Physical Chemistry* 3rd ed, Ch 35.9.
# -   Bessey & Bessey, *Am. Natur.*, 376, 1898, 263

# %% [markdown]
# # Dissociation energies of CFCs

# %% [markdown]
# Bromine and chlorine containing compounds are problematic because they catalyze the decomposition of ozone.

# %%
h2kj_mol = 2625.50   # Hartree to kJ/mol
h2kcal_mol = 627.509 # Hartree to kcal/mol

Eopt = -499.0931526167 # hartree; optimized energy of CH3Cl from webmo
Rs, Es = np.genfromtxt("ch3cl-scan1237.csv", skip_header=1, delimiter=',', unpack=True)
# fig, ax = plt.subplots()
# ax.plot(Rs, Es, '-o' )
BEch3cl = (Es[-1] - Eopt) * h2kj_mol # kJ/mol
BEch3cl
# Out:
# np.float64(783.1593886458593)

# %% [markdown]
# CH<sub>3</sub>Br bond energy.

# %%
E_max = -2611.444783 # hartree; E at 10AA
BEch3br = (E_max + 2611.717972610017) * h2kj_mol
BEch3br
# Out:
# 717.2593211001533

# %% [markdown]
# # Plotting and FFT of wav

# %% [markdown]
# Scipy can plot wav files.

# %%
from scipy.io.wavfile import read
import matplotlib.pyplot as plt

# read audio samples
sample_rate12C, data_12C = read("./cricket-data/585ssj.wav")
sample_rate30C, data_30C = read("./cricket-data/585ssh.wav")
length = data_12C.shape[0]/sample_rate12C # seconds
time12C = np.linspace(0, length, data_12C.shape[0])
time30C = np.linspace(0, length, data_30C.shape[0])

fig, ax = plt.subplots(2,1, figsize=(10,5))
ax[0].plot(time12C, data_12C, lw=0.25)
ax[1].plot(time30C, data_30C, lw=0.25);
